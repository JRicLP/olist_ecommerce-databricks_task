# %%
# Célula de verificação
import requests

# Verificando os CSVs presentes no volume
files = dbutils.fs.ls("/Volumes/workspace/olist_ecommerce/raw_data")
print(f"Arquivos encontrados: {len(files)}")
for f in files: print(f.name)

# Testando o acesso à API do Banco Central
try:
    r = requests.get("", timeout=5)
    print("\nAPI BCB: OK", r.status_code)
except Exception as e:
    print("\nAPI BCB: BLOQUEADA —", e)
# Out:
# Arquivos encontrados: 9
# olist_customers_dataset.csv
# olist_geolocation_dataset.csv
# olist_order_items_dataset.csv
# olist_order_payments_dataset.csv
# olist_order_reviews_dataset.csv
# olist_orders_dataset.csv
# olist_products_dataset.csv
# olist_sellers_dataset.csv
# product_category_name_translation.csv
#
# API BCB: OK 200
